# %%
import pandas as pd 
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('US_fatalities.csv')

# %%
df2=pd.read_csv('India fatalities.csv')

# %%
df3=pd.read_csv('Australian fatilities.csv')

# %%
df1.head()
# Out:
#    Year  Number of fatal Accidents
# 0  1992                         98
# 1  1993                         98
# 2  1994                         85
# 3  1995                        100
# 4  1996                         86

# %%
df2.head()
# Out:
#    Year  Number of  Fatal Accidents  Number of Serious Accidents
# 0  1992                         165                          810
# 1  1993                         156                          854
# 2  1994                         156                          717
# 3  1995                         137                          757
# 4  1996                         131                          677

# %%
df3.head()
# Out:
#    Year   Number of Fatal Accidents
# 0   1992                          2
# 1   1993                          2
# 2   1994                          3
# 3   1995                          2
# 4   1996                          8

# %%
df2.drop('Number of Serious Accidents',axis=1,inplace=True)

# %%
import sys

# %%
plt.figure(figsize=(10,10))
plt.xlabel("Year")
plt.ylabel("Number of Fatal Accidents")

line1=plt.plot(df2["Year"],df2['Number of  Fatal Accidents'],marker='o',label="India")
line2=plt.plot(df3["Year "],df3['Number of Fatal Accidents'],marker='o',label="Australia")
line3=plt.plot(df1["Year"],df1['Number of fatal Accidents'],marker='o',label="US")
plt.legend()

# %%
df1.columns
# Out:
# Index(['Year', 'Number of fatal Accidents'], dtype='object')

# %%
df2.columns
# Out:
# Index(['Year', 'Number of  Fatal Accidents'], dtype='object')

# %%
df3.columns
# Out:
# Index(['Year ', 'Number of Fatal Accidents'], dtype='object')

# %%
plt.figure(figsize=(15,8))
plt.title("Fatalities in Indian Underground mines 1992-2015")
sb.barplot(x=df1['Year'],y=df1['Number of fatal Accidents'])

# %%
plt.figure(figsize=(15,8))
plt.title("Fatalities in US Underground mines 1992-2015")
sb.barplot(x=df2['Year'],y=df2['Number of  Fatal Accidents'])

# %%
plt.figure(figsize=(15,8))
plt.title("Fatalities in Australian Underground mines 1992-2015")
sb.barplot(x=df3['Year '],y=df3['Number of Fatal Accidents'])
